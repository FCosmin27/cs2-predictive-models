# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('data/match_data.csv')
df.head()
# Out:
#          Date   Team1          Team2  Score  Team1_Position  \
# 0  28/03/2024  spirit           faze      0               4
# 1  28/03/2024  spirit  natus_vincere      1               4
# 2  28/03/2024  spirit       imperial      1               4
# 3  28/03/2024  spirit         cloud9      1               4
# 4  28/03/2024  spirit      metizport      1               4
#
#    Team1_Win_Percentage  Team2_Position  Team2_Win_Percentage  \
# 0                  79.2               1                  72.4
# 1                  79.2               2                  77.3
# 2                  79.2              18                  72.0
# 3                  79.2               7                  63.0
# 4                  79.2              30                  62.0
#
#    Team1_Player1_Rating  Team1_Player1_Kills_Per_Round  ...  \
# 0                  1.03                           0.63  ...
# 1                  1.03                           0.63  ...
# 2                  1.03                           0.63  ...
# 3                  1.03                           0.63  ...
# 4                  1.03                           0.63  ...
#
#    Team2_Player3_Deaths_Per_Round  Team2_Player3_Headshots  \
# 0                            0.63                     54.0
# 1                            0.65                     65.9
# 2                            0.64                     48.6
# 3                            0.65                     35.8
# 4                            0.66                     55.2
#
#    Team2_Player4_Rating  Team2_Player4_Kills_Per_Round  \
# 0                  1.12                           0.71
# 1                  1.16                           0.73
# 2                  1.14                           0.73
# 3                  1.09                           0.65
# 4                  1.10                           0.68
#
#    Team2_Player4_Deaths_Per_Round  Team2_Player4_Headshots  \
# 0                            0.60                     52.5
# 1                            0.65                     51.2
# 2                            0.61                     52.2
# 3                            0.67                     48.0
# 4                            0.68                     55.5
#
#    Team2_Player5_Rating  Team2_Player5_Kills_Per_Round  \
# 0                  1.18                           0.74
# 1                  1.17                           0.74
# 2                  1.11                           0.69
# 3                  1.12                           0.68
# 4                  1.09                           0.66
#
#    Team2_Player5_Deaths_Per_Round  Team2_Player5_Headshots
# 0                            0.59                     35.1
# 1                            0.57                     38.4
# 2                            0.66                     53.5
# 3                            0.57                     45.9
# 4                            0.66                     52.3
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Team1', 'Team2', 'Score', 'Team1_Position',
#        'Team1_Win_Percentage', 'Team2_Position', 'Team2_Win_Percentage',
#        'Team1_Player1_Rating', 'Team1_Player1_Kills_Per_Round',
#        'Team1_Player1_Deaths_Per_Round', 'Team1_Player1_Headshots',
#        'Team1_Player2_Rating', 'Team1_Player2_Kills_Per_Round',
#        'Team1_Player2_Deaths_Per_Round', 'Team1_Player2_Headshots',
#        'Team1_Player3_Rating', 'Team1_Player3_Kills_Per_Round',
#        'Team1_Player3_Deaths_Per_Round', 'Team1_Player3_Headshots',
#        'Team1_Player4_Rating', 'Team1_Player4_Kills_Per_Round',
#        'Team1_Player4_Deaths_Per_Round', 'Team1_Player4_Headshots',
#        'Team1_Player5_Rating', 'Team1_Player5_Kills_Per_Round',
#        'Team1_Player5_Deaths_Per_Round', 'Team1_Player5_Headshots',
#        'Team2_Player1_Rating', 'Team2_Player1_Kills_Per_Round',
#        'Team2_Player1_Deaths_Per_Round', 'Team2_Player1_Headshots',
#        'Team2_Player2_Rating', 'Team2_Player2_Kills_Per_Round',
#        'Team2_Player2_Deaths_Per_Round', 'Team2_Player2_Headshots',
#        'Team2_Player3_Rating', 'Team2_Player3_Kills_Per_Round',
#        'Team2_Player3_Deaths_Per_Round', 'Team2_Player3_Headshots',
#        'Team2_Player4_Rating', 'Team2_Player4_Kills_Per_Round',
#        'Team2_Player4_Deaths_Per_Round', 'Team2_Player4_Headshots',
#        'Team2_Player5_Rating', 'Team2_Player5_Kills_Per_Round',
#        'Team2_Player5_Deaths_Per_Round', 'Team2_Player5_Headshots'],
#       dtype='object')

# %%
df = df.drop(['Date', 'Team1', 'Team2'], axis = 1)
df.head()
# Out:
#    Score  Team1_Position  Team1_Win_Percentage  Team2_Position  \
# 0      0               4                  79.2               1
# 1      1               4                  79.2               2
# 2      1               4                  79.2              18
# 3      1               4                  79.2               7
# 4      1               4                  79.2              30
#
#    Team2_Win_Percentage  Team1_Player1_Rating  Team1_Player1_Kills_Per_Round  \
# 0                  72.4                  1.03                           0.63
# 1                  77.3                  1.03                           0.63
# 2                  72.0                  1.03                           0.63
# 3                  63.0                  1.03                           0.63
# 4                  62.0                  1.03                           0.63
#
#    Team1_Player1_Deaths_Per_Round  Team1_Player1_Headshots  \
# 0                            0.64                     56.1
# 1                            0.64                     56.1
# 2                            0.64                     56.1
# 3                            0.64                     56.1
# 4                            0.64                     56.1
#
#    Team1_Player2_Rating  ...  Team2_Player3_Deaths_Per_Round  \
# 0                  1.21  ...                            0.63
# 1                  1.21  ...                            0.65
# 2                  1.21  ...                            0.64
# 3                  1.21  ...                            0.65
# 4                  1.21  ...                            0.66
#
#    Team2_Player3_Headshots  Team2_Player4_Rating  \
# 0                     54.0                  1.12
# 1                     65.9                  1.16
# 2                     48.6                  1.14
# 3                     35.8                  1.09
# 4                     55.2                  1.10
#
#    Team2_Player4_Kills_Per_Round  Team2_Player4_Deaths_Per_Round  \
# 0                           0.71                            0.60
# 1                           0.73                            0.65
# 2                           0.73                            0.61
# 3                           0.65                            0.67
# 4                           0.68                            0.68
#
#    Team2_Player4_Headshots  Team2_Player5_Rating  \
# 0                     52.5                  1.18
# 1                     51.2                  1.17
# 2                     52.2                  1.11
# 3                     48.0                  1.12
# 4                     55.5                  1.09
#
#    Team2_Player5_Kills_Per_Round  Team2_Player5_Deaths_Per_Round  \
# 0                           0.74                            0.59
# 1                           0.74                            0.57
# 2                           0.69                            0.66
# 3                           0.68                            0.57
# 4                           0.66                            0.66
#
#    Team2_Player5_Headshots
# 0                     35.1
# 1                     38.4
# 2                     53.5
# 3                     45.9
# 4                     52.3
#
# [5 rows x 45 columns]

# %%
df['Team1_Position'].count()
# Out:
# 2555

# %%
y = df['Score']
y.dtype
# Out:
# dtype('int64')

# %%
X = df.drop(['Score'], axis = 1)
X.head()
# Out:
#    Team1_Position  Team1_Win_Percentage  Team2_Position  Team2_Win_Percentage  \
# 0               4                  79.2               1                  72.4
# 1               4                  79.2               2                  77.3
# 2               4                  79.2              18                  72.0
# 3               4                  79.2               7                  63.0
# 4               4                  79.2              30                  62.0
#
#    Team1_Player1_Rating  Team1_Player1_Kills_Per_Round  \
# 0                  1.03                           0.63
# 1                  1.03                           0.63
# 2                  1.03                           0.63
# 3                  1.03                           0.63
# 4                  1.03                           0.63
#
#    Team1_Player1_Deaths_Per_Round  Team1_Player1_Headshots  \
# 0                            0.64                     56.1
# 1                            0.64                     56.1
# 2                            0.64                     56.1
# 3                            0.64                     56.1
# 4                            0.64                     56.1
#
#    Team1_Player2_Rating  Team1_Player2_Kills_Per_Round  ...  \
# 0                  1.21                           0.74  ...
# 1                  1.21                           0.74  ...
# 2                  1.21                           0.74  ...
# 3                  1.21                           0.74  ...
# 4                  1.21                           0.74  ...
#
#    Team2_Player3_Deaths_Per_Round  Team2_Player3_Headshots  \
# 0                            0.63                     54.0
# 1                            0.65                     65.9
# 2                            0.64                     48.6
# 3                            0.65                     35.8
# 4                            0.66                     55.2
#
#    Team2_Player4_Rating  Team2_Player4_Kills_Per_Round  \
# 0                  1.12                           0.71
# 1                  1.16                           0.73
# 2                  1.14                           0.73
# 3                  1.09                           0.65
# 4                  1.10                           0.68
#
#    Team2_Player4_Deaths_Per_Round  Team2_Player4_Headshots  \
# 0                            0.60                     52.5
# 1                            0.65                     51.2
# 2                            0.61                     52.2
# 3                            0.67                     48.0
# 4                            0.68                     55.5
#
#    Team2_Player5_Rating  Team2_Player5_Kills_Per_Round  \
# 0                  1.18                           0.74
# 1                  1.17                           0.74
# 2                  1.11                           0.69
# 3                  1.12                           0.68
# 4                  1.09                           0.66
#
#    Team2_Player5_Deaths_Per_Round  Team2_Player5_Headshots
# 0                            0.59                     35.1
# 1                            0.57                     38.4
# 2                            0.66                     53.5
# 3                            0.57                     45.9
# 4                            0.66                     52.3
#
# [5 rows x 44 columns]

# %%
def standardize_features(X):
    return (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# %%
X = standardize_features(X)

# %%
X.head()
# Out:
#    Team1_Position  Team1_Win_Percentage  Team2_Position  Team2_Win_Percentage  \
# 0       -1.051453               1.65133       -1.264441              1.042065
# 1       -1.051453               1.65133       -1.206761              1.412826
# 2       -1.051453               1.65133       -0.283884              1.011798
# 3       -1.051453               1.65133       -0.918362              0.330808
# 4       -1.051453               1.65133        0.408274              0.255143
#
#    Team1_Player1_Rating  Team1_Player1_Kills_Per_Round  \
# 0             -0.231966                      -0.272536
# 1             -0.231966                      -0.272536
# 2             -0.231966                      -0.272536
# 3             -0.231966                      -0.272536
# 4             -0.231966                      -0.272536
#
#    Team1_Player1_Deaths_Per_Round  Team1_Player1_Headshots  \
# 0                       -0.313153                 0.900032
# 1                       -0.313153                 0.900032
# 2                       -0.313153                 0.900032
# 3                       -0.313153                 0.900032
# 4                       -0.313153                 0.900032
#
#    Team1_Player2_Rating  Team1_Player2_Kills_Per_Round  ...  \
# 0              1.167393                        0.97813  ...
# 1              1.167393                        0.97813  ...
# 2              1.167393                        0.97813  ...
# 3              1.167393                        0.97813  ...
# 4              1.167393                        0.97813  ...
#
#    Team2_Player3_Deaths_Per_Round  Team2_Player3_Headshots  \
# 0                       -0.208777                 0.361315
# 1                        0.254064                 1.548783
# 2                        0.022644                -0.177535
# 3                        0.254064                -1.454811
# 4                        0.485485                 0.481060
#
#    Team2_Player4_Rating  Team2_Player4_Kills_Per_Round  \
# 0              0.501169                       0.620592
# 1              1.014442                       0.981164
# 2              0.757806                       0.981164
# 3              0.116215                      -0.461122
# 4              0.244533                       0.079735
#
#    Team2_Player4_Deaths_Per_Round  Team2_Player4_Headshots  \
# 0                       -1.280110                 0.208757
# 1                       -0.023992                 0.052045
# 2                       -1.028887                 0.172593
# 3                        0.478456                -0.333706
# 4                        0.729680                 0.570399
#
#    Team2_Player5_Rating  Team2_Player5_Kills_Per_Round  \
# 0              0.641470                       0.585975
# 1              0.546320                       0.585975
# 2             -0.024579                      -0.082940
# 3              0.070571                      -0.216723
# 4             -0.214879                      -0.484290
#
#    Team2_Player5_Deaths_Per_Round  Team2_Player5_Headshots
# 0                       -1.200167                -1.828370
# 1                       -1.644802                -1.443074
# 2                        0.356056                 0.319949
# 3                       -1.644802                -0.567400
# 4                        0.356056                 0.179842
#
# [5 rows x 44 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.53      0.57       520
#            1       0.57      0.65      0.61       502
#
#     accuracy                           0.59      1022
#    macro avg       0.59      0.59      0.59      1022
# weighted avg       0.59      0.59      0.59      1022
#
# [[276 244]
#  [175 327]]
